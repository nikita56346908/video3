# %%
(sudo) pip install moviepy
# Out:
#   File "<ipython-input-1-c812a21b4fbc>", line 1
#     (sudo) pip install moviepy
#              ^
# SyntaxError: invalid syntax

# %%
pip install moviepy
# Out:
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.1-cp37-none-any.whl size=110791 sha256=fe3d07a71d114c3e613a44d3635724d626a3367b692ea1e9bda8930a5e0e6acf
#   Stored in directory: C:\Users\hamme\AppData\Local\pip\Cache\wheels\a3\3c\07\45afe2bd5dbd3f935f445545d645f0f8c05d48340136367d45
# ...
#   Created wheel for proglog: filename=proglog-0.1.9-cp37-none-any.whl size=6152 sha256=abd3b4e3bb842e77b5e4b60f6d488cdd1df36fe145fc59e23cb91f8d34f7f7a9
#   Stored in directory: C:\Users\hamme\AppData\Local\pip\Cache\wheels\65\56\60\1d0306a8d90b188af393c1812ddb502a8821b70917f82dcc00
# Successfully built moviepy proglog
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install youtube-dl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cd /d C:
# Out:
# [WinError 123] Синтаксическая ошибка в имени файла, имени папки или метке тома: '/d C:'
# C:\Users\hamme

# %%
youtube-dl jjwjUoUMI9g -o
# Out:
#   File "<ipython-input-2-98b13dc95c4d>", line 1
#     youtube-dl jjwjUoUMI9g -o
#                          ^
# SyntaxError: invalid syntax

# %%
from moviepy.editor import *
video = VideoFileClip('clipp.mp4', audio = False
# Out:
#   File "<ipython-input-4-cf28552dea82>", line 2
#     video = VideoFileClip('clipp.mp4', audio = False
#                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
from moviepy.editor import *

# %%
video = VideoFileClip('clipp.mp4', audio = False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-393f1d7df336> in <module>
# ----> 1 video = VideoFileClip('clipp.mp4', audio = False)
#
# ~\Anaconda3\lib\site-packages\moviepy\video\io\VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
# ---> 91                                          fps_source=fps_source)
#      92
#      93         # Make some of the reader's attributes accessible from the clip
#
# ~\Anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_reader.py in __init__(self, filename, print_infos, bufsize, pix_fmt, check_duration, target_resolution, resize_algo, fps_source)
# ...

# %%
video = VideoFileClip('clipp.mp4', audio = False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-393f1d7df336> in <module>
# ----> 1 video = VideoFileClip('clipp.mp4', audio = False)
#
# ~\Anaconda3\lib\site-packages\moviepy\video\io\VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
# ---> 91                                          fps_source=fps_source)
#      92
#      93         # Make some of the reader's attributes accessible from the clip
#
# ~\Anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_reader.py in __init__(self, filename, print_infos, bufsize, pix_fmt, check_duration, target_resolution, resize_algo, fps_source)
# ...

# %%
video = VideoFileClip('clipp.mp4', audio = False)

# %%
video = VideoFileClip('clipp.mp4', audio = False)

# %%
from moviepy.editor import *

video = VideoFileClip('clipp.mp4', audio = False)

video.write_videofile('myclipp.mp4')
# Out:
# Moviepy - Building video myclipp.mp4.
# Moviepy - Writing video myclipp.mp4
# Moviepy - Done !
# Moviepy - video ready myclipp.mp4

# %%
video = VideoFileClip('myclipp.mp4').subclip('00:00:34', '00:02:34')

video.write_videofile('myclippobrez.mp4')
# Out:
# Moviepy - Building video myclippobrez.mp4.
# Moviepy - Writing video myclippobrez.mp4
# Moviepy - Done !
# Moviepy - video ready myclippobrez.mp4

# %%
audio = AudioFileClip('Ozzy.mp3')

video1 = video.set_audio(audio)

video.write_videofile('clippozzy.mp4')
# Out:
# Moviepy - Building video clippozzy.mp4.
# Moviepy - Writing video clippozzy.mp4
# Moviepy - Done !
# Moviepy - video ready clippozzy.mp4

# %%
video = VideoFileClip('clippobrez.mp4')

audio = AudioFileClip('Ozzy.mp3')

video1 = video.set_audio(audio)

video.write_videofile('clippozzy.mp4')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-e07cf3e400e0> in <module>
# ----> 1 video = VideoFileClip('clippobrez.mp4')
#       2
#       3 audio = AudioFileClip('Ozzy.mp3')
#       4
#       5 video1 = video.set_audio(audio)
#
# ~\Anaconda3\lib\site-packages\moviepy\video\io\VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
# ---> 91                                          fps_source=fps_source)
#      92
#      93         # Make some of the reader's attributes accessible from the clip
#
# ...

# %%
video = VideoFileClip('myclippobrez.mp4')

audio = AudioFileClip('Ozzy.mp3')

video1 = video.set_audio(audio)

video.write_videofile('clippozzy.mp4')
# Out:
# Moviepy - Building video clippozzy.mp4.
# Moviepy - Writing video clippozzy.mp4
# Moviepy - Done !
# Moviepy - video ready clippozzy.mp4

# %%
video = VideoFileClip('myclippobrez.mp4', audio = False).subclip('00:00:00','00:01:59')

audio = AudioFileClip('Ozzy.mp3').subclip('00:00:00', '00:01:59')

video1 = video.set_audio(audio)

video.write_videofile('clippozzy.mp4')
# Out:
# Moviepy - Building video clippozzy.mp4.
# Moviepy - Writing video clippozzy.mp4
# Moviepy - Done !
# Moviepy - video ready clippozzy.mp4

# %%
from moviepy.editor import *

video = VideoFileClip('myclippobrez.mp4', audio = False).subclip('00:00:00','00:01:59')

audio = AudioFileClip('Ozzy.mp3').subclip('00:00:00', '00:01:59')

video1 = video.set_audio(audio)

video1.write_videofile('clippozzy.mp4')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-404548bf6249> in <module>
#       1 from moviepy.editor import *
#       2
# ----> 3 video = VideoFileClip('myclippobrez.mp4', audio = False).subclip('00:00:00','00:01:59')
#       4
#       5 audio = AudioFileClip('Ozzy.mp3').subclip('00:00:00', '00:01:59')
#
# ~\Anaconda3\lib\site-packages\moviepy\video\io\VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
# ---> 91                                          fps_source=fps_source)
#      92
#      93         # Make some of the reader's attributes accessible from the clip
#
# ...

# %%
audioclip = AudioFileClip("Ozzy.mp3")
videoclip = VideoFileClip("myclippobrez.mp4")
finalclip = videoclip.set_audio(audioclip)
finalclip.subclip(0,3).write_videofile("clippozzy.mp4")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-99e0884274f4> in <module>
# ----> 1 audioclip = AudioFileClip("Ozzy.mp3")
#       2 videoclip = VideoFileClip("myclippobrez.mp4")
#       3 finalclip = videoclip.set_audio(audioclip)
#       4 finalclip.subclip(0,3).write_videofile("clippozzy.mp4")
#
# ~\Anaconda3\lib\site-packages\moviepy\audio\io\AudioFileClip.py in __init__(self, filename, buffersize, nbytes, fps)
#      70         self.filename = filename
#      71         self.reader = FFMPEG_AudioReader(filename, fps=fps, nbytes=nbytes,
# ---> 72                                          buffersize=buffersize)
#      73         self.fps = fps
#      74         self.duration = self.reader.duration
#
# ~\Anaconda3\lib\site-packages\moviepy\audio\io\readers.py in __init__(self, filename, buffersize, print_infos, fps, nbytes, nchannels)
# ...

# %%
from moviepy.editor import *

video = VideoFileClip('myclippobrez.mp4', audio = False).subclip('00:00:00','00:01:59')

audio = AudioFileClip('Ozzy.mp3').subclip('00:00:00', '00:01:59')

video1 = video.set_audio(audio)

video1.write_videofile('clippozzy.mp4')
# Out:
# Moviepy - Building video clippozzy.mp4.
# MoviePy - Writing audio in clippozzyTEMP_MPY_wvf_snd.mp3
# ...
# chunk:  99%|█████████▉| 2610/2624 [00:19<00:00, 142.27it/s, now=None]
# MoviePy - Done.
# Moviepy - Writing video clippozzy.mp4
# ...
# t:  65%|██████▌   | 2324/3570 [01:20<00:51, 24.29it/s, now=None]
# ...
# ...
# t: 100%|█████████▉| 3569/3570 [02:19<00:00, 30.57it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready clippozzy.mp4
# t:  12%|█▏        | 419/3570 [03:00<01:22, 38.13it/s, now=None]

# %%
from moviepy.editor import *

Clip1 = VideoFileClip('clippozzy.mp4')
Clip2 = VideoFileClip('myclippobrez.mp4').resize(45,150)
Clip3 = CompositeVideoClip([Clip1, Clip2.set_pos((1, 2))])
Clip3.write_videofile('2clipps.mp4', fps = Clip1.fps)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-fa5ae9dd47a3> in <module>
#       3 Clip1 = VideoFileClip('clippozzy.mp4')
#       4 Clip2 = VideoFileClip('myclippobrez.mp4').resize(45,150)
# ----> 5 Clip3 = CompositeVideoClip([Clip1, Clip2.set_pos((1, 2))])
#       6 Clip3.write_videofile('2clipps.mp4', fps = Clip1.fps)
#
# ~\Anaconda3\lib\site-packages\moviepy\video\compositing\CompositeVideoClip.py in __init__(self, clips, size, bg_color, use_bgclip, ismask)
#     105                           c.add_mask().mask).set_position(c.pos)
#     106                           .set_end(c.end).set_start(c.start, change_end=False)
# --> 107                           for c in self.clips]
#     108
#     109             self.mask = CompositeVideoClip(maskclips,self.size, ismask=True,
#
# ...

# %%
from moviepy.editor import *
from moviepy.config import change_settings
change_settings({'IMAGEMAGICK_BINARY': r"C:\Program Files\ImageMagick-7.0.10-Q16\magick.exe"})
video = VideoFileClip('clippozzy.mp4')
txt = TextClip('Это видео с котами', color = 'red', bg_color = 'white')
video1 = CompositeVideoClip([video, txt])
video1.write_videofile('clippozzy1.mp4')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-194cb18a7a56> in <module>
#       2 from moviepy.config import change_settings
#       3 change_settings({'IMAGEMAGICK_BINARY': r"C:\Program Files\ImageMagick-7.0.10-Q16\magick.exe"})
# ----> 4 video = VideoFileClip('clippozzy.mp4')
#       5 txt = TextClip('Это видео с котами', color = 'red', bg_color = 'white')
#       6 video1 = CompositeVideoClip([video, txt])
#
# ~\Anaconda3\lib\site-packages\moviepy\video\io\VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
# ---> 91                                          fps_source=fps_source)
# ...
